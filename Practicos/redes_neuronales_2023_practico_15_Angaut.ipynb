# %% [markdown]
# <a href="https://colab.research.google.com/github/gonzaloangaut/NeuralNetworks/blob/main/Practicos/redes_neuronales_2023_practico_15_Angaut.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PyTorch: Autoencoder convolucional Fashion-MNIST
#
# ## Refs.
#
# * https://pytorch.org/tutorials/beginner/basics/optimization_tutorial.html
#
# * https://github.com/zalandoresearch/fashion-mnist
#
# * https://github.com/pranay414/Fashion-MNIST-Pytorch/blob/master/fashion_mnist.ipynb
#
# ## **Ejercicio 1)** Importando librerías
#
# **0)** De ser necesario, **instale PyTorch** escribiendo
#
#     !pip3 install torch torchvision torchaudio torchviz
#
# **1)** Importe las librerías estandard de Python: `os`, `datetime`, `collections` y `pickle`.
#
# **2)** Importe las siguientes librerías third party de Python: `matplotlib.pyplot`, `numpy`, `scipy`, `sklearn`, `pandas`, `dill` y `json`.
#
# **3)** Importe las librerias necesarias de **PyTorch**: `torch` y `torchvision`.
#
# **4)** Importe la librería: `google.colab`.

# %%
# 1.0)
# !pip3 install torch torchvision torchaudio torchviz
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.16.0+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.1.0+cu121)
# Requirement already satisfied: torchviz in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from torchviz) (0.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
# 1.1)
import os
import pickle
import datetime
from collections import defaultdict

# %%
# 1.2)
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
import scipy as sp
import scipy.linalg as linalg
import sklearn as skl
import pandas as pd
#import dill
import json

# %%
# 1.3)
import torch
import torch.optim as optim
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader, Subset, random_split
from torchvision import datasets
from torchvision import transforms
from torchvision.io import read_image
from torchvision.transforms import ToTensor, Lambda, Compose
#from torchviz import make_dot

# %%
# 1.4)
import google.colab
from google.colab import files

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %% [markdown]
# ## **Ejercicio 2)**
#
# Bajando y Jugando con el dataset **Fashion-MNIST**.
#
# **1)** Baje y transforme los conjuntos de entrenamiento y testeo de FashionMNIST.
#
# **2)** Grafique un mosaico de 3x3 imagenes de FashionMNIST, cada una titulada con su respectiva clasificación

# %%
# 2.1)
# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor()
                                #,transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                               ])

# Download and load the training data
train_set_orig = datasets.FashionMNIST('MNIST_data/', download = True, train = True,  transform = transform)
valid_set_orig = datasets.FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)

# %%
# 2.2)
labels_names = {
    0: "T-Shirt",    # Remera manga corta
    1: "Trouser",    # Pantalon
    2: "Pullover",   # Buzo
    3: "Dress",      # Vestido
    4: "Coat",       # Abrigo
    5: "Sandal",     # Sandalia
    6: "Shirt",      # Remera manga larga
    7: "Sneaker",    # Zapatilla
    8: "Bag",        # Bolso
    9: "Ankle Boot", # Bota
}

figure = plt.figure()
cols,rows = 3,3
for i in range(1,cols*rows+1):
    j = torch.randint(len(train_set_orig),size=(1,)).item() # Los números aleatorios tambien se pueden generar desde pytorch. Util para trabajar en la GPU.
    # eligiendo el j así estamos viendo 9 imagenes al azar del conjunto, o sea, pueden repetirse el tipo
    image,label = train_set_orig[j]
    figure.add_subplot(rows,cols,i)
    plt.title(labels_names[label])
    plt.axis("off")
    plt.imshow(image.squeeze(),cmap="Greys_r")
plt.show()

# %% [markdown]
# ## Ejercicio 3) Creando un `DataSet` personalizado.
#
# **1)** Con el fin de implementar un autoencoder, cree una clase derivada de la clase `DataSet` (llámela, por ejemplo `CustomDataset`) que, en vez de retornal el label asociado a cada imagen de `FashionMNIST`, retorne la imagen misma.
#
# **2)** Utilice dicha clase para transformar los conjuntos de entrenamiento y testeo de `FashionMNIST` pensados para clasificación, a correspondientes conjuntos pensados para entrenar un autoencoder.
# Para ello, defina una clase `CustomDataset` que deriva de la clase `Dataset`, cuyo método `__getitem__(self,i)` retorne el pair `input,output` donde tanto `input` cómo `output` son iguales a la $i$-ésima imagen del dataset.

# %%
# 3.1)
# Creamos una subclase de Dataset que nos sirva para muestrear imagenes en el entrenamiento del autoencoder
class CustomDataset(Dataset):
    def __init__(self,dataset):
        self.dataset=dataset
    # Redefinimos el método .__len__()
    def __len__(self):
        return len(self.dataset)
    # Redefinimos el método .__getitem__()
    def __getitem__(self,i):
        image,label=self.dataset[i]
        input  = image
        #output = torch.flatten(image) # Reescribimos el label original con una version achatada de la imagen.
        output = image
        return input,output

# %%
# 3.2)
# Convertimos FashionMNIST Dataset a CustomDataset
train_set = CustomDataset(train_set_orig)
valid_set = CustomDataset(valid_set_orig)

# %% [markdown]
# ## Ejercicio 4) Red Neuronal Autoencoder
#
# **1)** Defina y cree una red neuronal autoenconder convolucional.
# El **encoder** deberá estar constituido por las siguientes capas:
#
# Primero una capa convolucional 2D constituida por:
#
# * Una capa `Conv2d` (ver https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html) que deberá mapear $1$ canal de entradas de dimensiones $28\times 28$ a $16$ canales de de salida de dimensiones $(26,26)$. Para ello utilice un kernel de dimensiones $(3,3)$ y el resto de los parámetros en sus valores por defecto.
# * Una capa `ReLU`.
# * Una capa `Dropout`.
# * Una capa `MaxPool` (ver https://pytorch.org/docs/stable/generated/torch.nn.MaxPool2d.html) con un kernel de dimensiones $(2,2)$, de manera que mapeará entradas de dimensiones $(26,26)$ a salidas de dimensiones $(13,13)$.
#
# Luego una capa lineal constituida por:
#
# * Una capa `Flatten` que mapea una entrada de $16$ canales de dimensiones $(13,13)$ a un vector de dimensión $16\times 13\times 13$.
# * Una capa `Linear` que mapea un vector de dimensión $16\times 13\times 13$ a un vector de dimensión $n$.
# * Una capa `ReLU`.
# * Una capa `Dropout`.
#
# El **decoder** deberá estar constituido por las siguientes capas:
#
# Primero una capa lineal constituida por:
#
# * Una capa `Linear` que mapea un vector de dimensión $n$ a un vector de dimensión $16\times 13\times 13$.
# * Una capa `ReLU`.
# * Una capa `Dropout`.
# * Una capa `Unflatten` que mapea un vector de entrada de dimensión $16\times 13\times 13$ a $16$ canales de dimensiones $(13,13)$.
#
# Luego una capa convolucional 2D transpuesta, constituida por:
#
# * una capa `ConvTranspose2d` (ver https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html) que mapea $16$ canales de dimensiones $(13,13)$ a $1$ canal de dimensiones $(28,28)$. Para ello, utilice un kernel de dimensiones $(4,4)$ y un stride de dimensiones $(2,2)$, dejando el resto de los parámetros en sus valores por defecto.
# * Una capa `Sigmoid`.
# * Una capa `Dropout`.
#
# **2)** Grafique, comparativamente, las imagenes a predecir vs las imagenes predichas por el modelo sin entrenar usando $n=64$ y dropout $p=0.2$.

# %%
# 4.1)
class AutoEncoderConv(nn.Module):
    def __init__(self,n,p=0.2): #  inicializa los atributos del objeto que creamos
        super(AutoEncoderConv, self).__init__()

        self.flatten = nn.Flatten() # "capa" flatten, achata el array

        # defino el encoder como secuencia
        self.encoder = nn.Sequential(
            # capa conv2d
            nn.Conv2d(1, 16, kernel_size=(3, 3), padding=0), # de 1 canal a 16, con kernel (3, 3). (1, 28, 28)==>(16, 26, 26). Se pierden 2 por la primera y ultima fila y primera y ultima columna.
            nn.ReLU(),
            nn.Dropout(p),
            nn.MaxPool2d(2, 2), # a cada canal lo reduce a la mitad. (16, 26, 26)==>(16, 13, 13)
            # capa lineal
            nn.Flatten(), # un vector de 16*13*13
            nn.Linear(16*13*13,n), # mapea un vector de 16*13*13 con uno de n (de la capa del medio)
            nn.ReLU(),
            nn.Dropout(p),
        )

        self.decoder = nn.Sequential(
            # capa lineal
            nn.Linear(n,16*13*13),
            nn.ReLU(),
            nn.Dropout(p),
            nn.Unflatten(1, (16, 13, 13)), # de 1 a 16 de 13x13
            # capa conv2d
            nn.ConvTranspose2d(16, 1, kernel_size=(4,4), stride=2), # (16, 13, 13) => (1, 28, 28). Es lo opuesto de conv2d y maxpool juntos, el kernel se mueve de a 2 (stride)
            nn.Sigmoid(),
            nn.Dropout(p),
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
# 4.2)
n = 64
model = AutoEncoderConv(n) # uso 64 neuronas en la capa intermedia

# %%
def batch(x):
  return x.unsqueeze(0) # (28,28)=>(1,28,28)

def unbatch(x):
  return x.squeeze().detach().cpu().numpy() # (1, 28, 28)=>(28, 28)

# %%
# Miramos que imagenes predice el modelo sin entrenar
figure = plt.figure()
rows,cols = 3,2
i = 0 # subplot index
for row in range(1,rows+1):
    j = torch.randint(len(train_set_orig),size=(1,)).item() # elegimos un elemento random de el conjunto de entrenamiento
    # Ploteamos la imagen original
    i += 1
    image,flatten_imagen = train_set_orig[j]
    figure.add_subplot(rows,cols,i)
    if row==1: # le ponemos titulo solo a la primera imagen
      plt.title("original")
    plt.axis("off")
    plt.imshow(unbatch(image),cmap="Greys_r") # plotemaos la original
    # Ploteamos la imagen predicha
    i += 1
    figure.add_subplot(rows,cols,i)
    if row==1:
      plt.title("predicha")
    plt.axis("off")
    image_pred = unbatch(model(batch(image)))
    plt.imshow(image_pred,cmap="Greys_r")
plt.show()

# %% [markdown]
# ## Ejercicio 5) Entrenando el modelo
#
# **1)** Implemente, en una función, un loop de entrenamiento que recorra los batchs (lotes).
#
# **2)** Implemente, en una función, un loop de prueba o validación que recorra los batchs.
#
# **3)** Inicialize dos `DataLoader`s llamados `train_loader` y `valid_loader` que estén definidos sobre  el `train_set` (conjunto de entranmiento) y el `valid_set` (conjunto de prueba) de Fashion-MNIST, respectivamente, y que usen batchs de 100 ejemplos.
#
# **4)** Cree una función de pérdida usando el **Error Cuadrático Medio**.
#
# **5)** Cree un optimizador con un learning rate igual a $10^{-3}$.
# Pruebe con **ADAM**.
#
# **6)** Cree una instancia del modelo con $n=64$ neuronas en la capa intermedia y dropout $p=0.2$.
#
# **7)** Especifique en que dispositivo (`device`) va a trabajar: en una **CPU** o en una **GPU**.
#
# **8)** Implemente un loop que itere sobre épocas de entrenamiento y validación, y que correspondientemente guarde en cuatro listas los valores de los promedios de la **CEL** y la **Precisión** en función de las épocas para cada conjunto.
#
# **IMPORTANTE:** No olvide copiar los batchs al dispositivo de trabajo.
#
# **9)** Entrene y valide el modelo.
#
# **10)** Use las listas del inciso **3.7)** para graficar en función de las épocas la **ECM** y la **Precisión** de **entrenamiento** y **validación**, respectivamente.
# Discuta y comente, cual es el número óptimo de épocas de entrenamiento?
#
# **11)** Grafique, comparativamente, algunas de las imagenes a predecir vs las imagenes predichas por el modelo entrenado.
#
# **12)** Repita para otros valores de $n$, el optimizador **SGD**, otros valores de **dropout**, otros valores de **learning-rate**, otros tamaños de **batchs** y agregando **ReLU**s (y dropouts) en la capa de salida.
# Que valores de estos hiperparámetros considera los más convenientes? Porqué?

# %%
# 5.3)
batch_size = 100
train_loader = DataLoader(train_set, batch_size=batch_size,shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=batch_size,shuffle=True)

# %%
# 5.1)
# Definimos la función de entrenamiento (loop de entrenamiento)
def train_loop(dataloader,model,loss_fn,optimizer): # le pasamos un cargador de datos, un modelo, una funcion de perdida (en este caso cross entropy) y optimizador
    # Activamos la maquinaria de entrenamiento del modelo. para calcular los gradientes
    model.train()
    # Definimos ciertas constantes
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    sum_loss = 0
    # Iteramos sobre lotes (batchs)
    for batch, (X, y) in enumerate(dataloader):
        # Copiamos las entradas y las salidas al dispositivo de trabajo
        X = X.to(device)
        y = y.to(device)
        # Calculamos la predicción del modelo y la correspondiente pérdida (error)
        pred = model(X)
        loss = loss_fn(pred,y)
        # Backpropagamos usando el optimizador proveido.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Imprimimos el progreso...
        loss_value = loss.item()
        sum_loss += loss_value
        if batch*batch_size % 10000 == 0:
            current = batch*len(X)
            print(f"@train_loop batch={batch:>5d} loss={loss_value:>7f}  muestras-procesadas=[{current:>5d}/{size:>5d}]")
    avg_loss = sum_loss/num_batches # el error total va a ser el promedio de los errores
    return avg_loss

# 5.2)
# De manera similar, definimos la función de validación
def valid_loop(dataloader,model,loss_fn):
    # Desactivamos la maquinaria de entrenamiento del modelo
    model.eval()
    # Definimos ciertas constantes
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    sum_loss = 0
    # Para testear, desactivamos el cálculo de gradientes.
    with torch.no_grad():
        # Iteramos sobre lotes (batches)
        for X,y in dataloader:
            # Copiamos las entradas y las salidas al dispositivo de trabajo
            X = X.to(device)
            y = y.to(device)
            # Calculamos las predicciones del modelo...
            pred = model(X)
            # y las correspondientes pérdidas (errores), los cuales vamos acumulando en un valor total.
            sum_loss += loss_fn(pred,y).item()
    # Calculamos la pérdida total y la fracción de clasificaciones correctas, y las imprimimos.
    avg_loss = sum_loss/num_batches
    print(f"@valid_loop avg_loss={avg_loss:>8f}")
    return avg_loss

# %%
# 5.4)
# Creamos una instancia de una función de pérdida, error cuadratico medio en este caso
loss_fn = nn.MSELoss() # Para autoencoder

# %%
# 5.6)
n = 64
model = AutoEncoderConv(n)

# %%
# 5.5)
# Creamos un optimizador ADAM
learning_rate = 1e-3 # necesario para definir
optimizer = torch.optim.Adam(model.parameters(),lr=learning_rate,eps=1e-08,weight_decay=0,amsgrad=False)

# %%
# 5.7)
# Determinamos en que dispositivo vamos a trabajar, una CPU o una GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Pasamos el modelo al dispositivo
model = model.to(device)

# %%
# 5.8) y 5.9)
# Finalmente, entrenamos iterando sobre épocas.
# Además, testeamos el modelo en cada una de ellas.
num_epochs = 100
list_train_avg_loss_incorrecta = []
list_train_avg_loss = []
list_valid_avg_loss = []
for epoch in range(num_epochs):
    print(" ")
    print(f"Epoch {epoch+1}\n-------------------------------")
    train_avg_loss_incorrecta = train_loop(train_loader,model,loss_fn,optimizer) #entrenamos
    # el de arriba es el incorrecto pq te tira el error a medida que va entrenando (el error cometido en el 1er ejemplo es mucho mas grande que en
    # el último). una vez que deja de entrenar, debemos validar los datos de entrenamiento para tener la curva que se compara
    train_avg_loss = valid_loop(train_loader,model,loss_fn) # ahora validamos los datos de entrenamiento
    valid_avg_loss = valid_loop(valid_loader,model,loss_fn) # validamos los de validación

    #armo listas
    list_train_avg_loss_incorrecta.append(train_avg_loss_incorrecta)
    list_train_avg_loss.append(train_avg_loss)
    list_valid_avg_loss.append(valid_avg_loss)
print("Done!")
# Out:
#
# Epoch 1
# -------------------------------
# @train_loop batch=    0 loss=0.196701  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.078658  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.071278  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.063605  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.070229  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.065398  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.033561
# @valid_loop avg_loss=0.033590
#
# Epoch 2
# -------------------------------
# @train_loop batch=    0 loss=0.062204  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.063985  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.060488  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.066397  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.065160  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057403  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.032729
# @valid_loop avg_loss=0.032727
#
# Epoch 3
# -------------------------------
# @train_loop batch=    0 loss=0.061899  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.060530  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.062165  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056563  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.060254  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.059915  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030615
# @valid_loop avg_loss=0.030613
#
# Epoch 4
# -------------------------------
# @train_loop batch=    0 loss=0.061354  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.062773  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.060993  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.065381  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.060818  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.066034  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029628
# @valid_loop avg_loss=0.029645
#
# Epoch 5
# -------------------------------
# @train_loop batch=    0 loss=0.060927  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057609  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.063589  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.057540  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.063044  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.060075  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030303
# @valid_loop avg_loss=0.030330
#
# Epoch 6
# -------------------------------
# @train_loop batch=    0 loss=0.055889  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.058366  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.062708  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058402  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057221  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057981  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029489
# @valid_loop avg_loss=0.029514
#
# Epoch 7
# -------------------------------
# @train_loop batch=    0 loss=0.061018  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056460  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057857  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.054692  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.060756  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.058805  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028804
# @valid_loop avg_loss=0.028839
#
# Epoch 8
# -------------------------------
# @train_loop batch=    0 loss=0.063260  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.066059  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.053898  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.059643  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.059119  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.060843  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028798
# @valid_loop avg_loss=0.028833
#
# Epoch 9
# -------------------------------
# @train_loop batch=    0 loss=0.060058  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.052525  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.055716  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.060177  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058213  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057319  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028439
# @valid_loop avg_loss=0.028486
#
# Epoch 10
# -------------------------------
# @train_loop batch=    0 loss=0.057075  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.059135  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057581  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.059709  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.052592  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.060585  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028047
# @valid_loop avg_loss=0.028094
#
# Epoch 11
# -------------------------------
# @train_loop batch=    0 loss=0.055795  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.052562  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057741  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.054374  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057642  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.055303  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.027767
# @valid_loop avg_loss=0.027823
#
# Epoch 12
# -------------------------------
# @train_loop batch=    0 loss=0.059281  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.061070  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057810  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.062804  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.059721  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.050865  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028070
# @valid_loop avg_loss=0.028135
#
# Epoch 13
# -------------------------------
# @train_loop batch=    0 loss=0.060656  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.058710  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059983  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.061844  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058271  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057469  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028431
# @valid_loop avg_loss=0.028497
#
# Epoch 14
# -------------------------------
# @train_loop batch=    0 loss=0.056726  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.062791  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057845  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.057212  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.053829  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.058294  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.027507
# @valid_loop avg_loss=0.027570
#
# Epoch 15
# -------------------------------
# @train_loop batch=    0 loss=0.055090  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057973  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.055808  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058906  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.056713  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.051104  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028446
# @valid_loop avg_loss=0.028516
#
# Epoch 16
# -------------------------------
# @train_loop batch=    0 loss=0.061326  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.061259  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.060159  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.057535  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058252  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.051712  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028319
# @valid_loop avg_loss=0.028373
#
# Epoch 17
# -------------------------------
# @train_loop batch=    0 loss=0.060566  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.052870  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.054348  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.060632  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.060648  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.058260  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028257
# @valid_loop avg_loss=0.028327
#
# Epoch 18
# -------------------------------
# @train_loop batch=    0 loss=0.053084  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.062757  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.061902  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.055360  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.059033  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057753  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.027997
# @valid_loop avg_loss=0.028078
#
# Epoch 19
# -------------------------------
# @train_loop batch=    0 loss=0.056010  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.059788  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.058822  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.055749  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057435  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.059749  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028049
# @valid_loop avg_loss=0.028115
#
# Epoch 20
# -------------------------------
# @train_loop batch=    0 loss=0.061089  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056296  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059043  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.060078  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.053930  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.054972  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028483
# @valid_loop avg_loss=0.028546
#
# Epoch 21
# -------------------------------
# @train_loop batch=    0 loss=0.059626  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.058619  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057515  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.059303  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.056747  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.061910  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028417
# @valid_loop avg_loss=0.028485
#
# Epoch 22
# -------------------------------
# @train_loop batch=    0 loss=0.052835  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057849  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.061145  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.057104  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058129  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.058539  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029143
# @valid_loop avg_loss=0.029198
#
# Epoch 23
# -------------------------------
# @train_loop batch=    0 loss=0.057628  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.054232  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057746  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.060180  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.062009  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.053507  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028590
# @valid_loop avg_loss=0.028649
#
# Epoch 24
# -------------------------------
# @train_loop batch=    0 loss=0.056140  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.058060  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057175  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.057885  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.065702  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.056667  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.027943
# @valid_loop avg_loss=0.028012
#
# Epoch 25
# -------------------------------
# @train_loop batch=    0 loss=0.058402  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.053637  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.058080  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.055624  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.059228  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.058614  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028301
# @valid_loop avg_loss=0.028372
#
# Epoch 26
# -------------------------------
# @train_loop batch=    0 loss=0.057572  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057026  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.054359  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058969  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057722  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057255  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028620
# @valid_loop avg_loss=0.028683
#
# Epoch 27
# -------------------------------
# @train_loop batch=    0 loss=0.055647  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.054525  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.066515  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.055225  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.055264  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057145  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028430
# @valid_loop avg_loss=0.028493
#
# Epoch 28
# -------------------------------
# @train_loop batch=    0 loss=0.055921  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.059042  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059866  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058190  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.056167  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.054466  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028779
# @valid_loop avg_loss=0.028844
#
# Epoch 29
# -------------------------------
# @train_loop batch=    0 loss=0.054398  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056247  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.054227  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056850  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.055242  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057186  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028864
# @valid_loop avg_loss=0.028911
#
# Epoch 30
# -------------------------------
# @train_loop batch=    0 loss=0.054190  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.055273  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.054079  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.057563  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.054212  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.062859  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028713
# @valid_loop avg_loss=0.028779
#
# Epoch 31
# -------------------------------
# @train_loop batch=    0 loss=0.060186  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.052794  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.054951  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056425  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.055263  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.062229  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029005
# @valid_loop avg_loss=0.029062
#
# Epoch 32
# -------------------------------
# @train_loop batch=    0 loss=0.055547  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.058084  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057652  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056485  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.056542  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.058566  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028706
# @valid_loop avg_loss=0.028764
#
# Epoch 33
# -------------------------------
# @train_loop batch=    0 loss=0.058456  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057960  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057284  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.052851  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.059804  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.053673  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029188
# @valid_loop avg_loss=0.029245
#
# Epoch 34
# -------------------------------
# @train_loop batch=    0 loss=0.060114  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057034  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.058846  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058607  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.053859  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057456  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029427
# @valid_loop avg_loss=0.029479
#
# Epoch 35
# -------------------------------
# @train_loop batch=    0 loss=0.050563  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057916  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.063899  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058250  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057593  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057713  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029309
# @valid_loop avg_loss=0.029365
#
# Epoch 36
# -------------------------------
# @train_loop batch=    0 loss=0.061269  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.060194  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.054807  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.057805  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.053959  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.056029  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029255
# @valid_loop avg_loss=0.029312
#
# Epoch 37
# -------------------------------
# @train_loop batch=    0 loss=0.051807  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.050864  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.056048  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.053896  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058392  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.055952  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028839
# @valid_loop avg_loss=0.028908
#
# Epoch 38
# -------------------------------
# @train_loop batch=    0 loss=0.056631  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.054842  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.054751  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.060422  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.051344  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.053863  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029335
# @valid_loop avg_loss=0.029389
#
# Epoch 39
# -------------------------------
# @train_loop batch=    0 loss=0.052651  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.055071  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.056426  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.061060  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058144  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.053703  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029210
# @valid_loop avg_loss=0.029274
#
# Epoch 40
# -------------------------------
# @train_loop batch=    0 loss=0.058234  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.063393  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.063122  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.059418  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.061011  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.052017  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029266
# @valid_loop avg_loss=0.029322
#
# Epoch 41
# -------------------------------
# @train_loop batch=    0 loss=0.056737  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056572  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.054655  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.052716  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.061205  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.056560  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029348
# @valid_loop avg_loss=0.029403
#
# Epoch 42
# -------------------------------
# @train_loop batch=    0 loss=0.055577  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.054173  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.058488  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.057600  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.059568  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.054011  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029459
# @valid_loop avg_loss=0.029517
#
# Epoch 43
# -------------------------------
# @train_loop batch=    0 loss=0.054452  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056891  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059300  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.053564  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.061570  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.055750  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030071
# @valid_loop avg_loss=0.030121
#
# Epoch 44
# -------------------------------
# @train_loop batch=    0 loss=0.054419  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056572  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.056932  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.053463  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.056645  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.060441  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.028675
# @valid_loop avg_loss=0.028742
#
# Epoch 45
# -------------------------------
# @train_loop batch=    0 loss=0.061917  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057964  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.061590  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.057811  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057416  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.055739  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029852
# @valid_loop avg_loss=0.029896
#
# Epoch 46
# -------------------------------
# @train_loop batch=    0 loss=0.056847  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056508  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.054135  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.057112  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.054179  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.056314  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029792
# @valid_loop avg_loss=0.029841
#
# Epoch 47
# -------------------------------
# @train_loop batch=    0 loss=0.057075  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.058550  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059653  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058773  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058803  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.056629  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029875
# @valid_loop avg_loss=0.029924
#
# Epoch 48
# -------------------------------
# @train_loop batch=    0 loss=0.060629  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.060394  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059473  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.059610  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.055016  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.052279  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029014
# @valid_loop avg_loss=0.029063
#
# Epoch 49
# -------------------------------
# @train_loop batch=    0 loss=0.051184  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.060011  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.054754  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.055471  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.059899  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.054451  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029826
# @valid_loop avg_loss=0.029882
#
# Epoch 50
# -------------------------------
# @train_loop batch=    0 loss=0.059118  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.052595  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059394  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058261  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.054162  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.056503  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029874
# @valid_loop avg_loss=0.029926
#
# Epoch 51
# -------------------------------
# @train_loop batch=    0 loss=0.061923  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.054661  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.054674  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056479  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058912  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.055024  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029818
# @valid_loop avg_loss=0.029870
#
# Epoch 52
# -------------------------------
# @train_loop batch=    0 loss=0.055878  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057699  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.052733  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.059006  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.061963  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.058174  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029656
# @valid_loop avg_loss=0.029722
#
# Epoch 53
# -------------------------------
# @train_loop batch=    0 loss=0.062531  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.061158  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.062411  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.057405  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.050735  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057838  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029731
# @valid_loop avg_loss=0.029789
#
# Epoch 54
# -------------------------------
# @train_loop batch=    0 loss=0.053189  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.055372  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059053  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.061030  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058338  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.053795  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029593
# @valid_loop avg_loss=0.029649
#
# Epoch 55
# -------------------------------
# @train_loop batch=    0 loss=0.053857  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.054623  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059700  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.052009  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057119  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.060024  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030504
# @valid_loop avg_loss=0.030542
#
# Epoch 56
# -------------------------------
# @train_loop batch=    0 loss=0.056307  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057804  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.055263  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.059065  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.054814  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.054893  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030536
# @valid_loop avg_loss=0.030578
#
# Epoch 57
# -------------------------------
# @train_loop batch=    0 loss=0.051994  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.059209  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057362  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058812  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.054584  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.058221  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029863
# @valid_loop avg_loss=0.029900
#
# Epoch 58
# -------------------------------
# @train_loop batch=    0 loss=0.055283  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057409  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.055645  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056818  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057428  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.056544  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030011
# @valid_loop avg_loss=0.030052
#
# Epoch 59
# -------------------------------
# @train_loop batch=    0 loss=0.056463  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.054728  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.056711  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.055769  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057677  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.052531  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029978
# @valid_loop avg_loss=0.030025
#
# Epoch 60
# -------------------------------
# @train_loop batch=    0 loss=0.057183  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.060202  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.055950  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.057899  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.059361  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.053293  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030268
# @valid_loop avg_loss=0.030310
#
# Epoch 61
# -------------------------------
# @train_loop batch=    0 loss=0.057007  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.052500  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057018  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056554  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.056647  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.063028  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030310
# @valid_loop avg_loss=0.030346
#
# Epoch 62
# -------------------------------
# @train_loop batch=    0 loss=0.054749  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.059512  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.055110  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.054507  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.053113  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.053834  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030670
# @valid_loop avg_loss=0.030703
#
# Epoch 63
# -------------------------------
# @train_loop batch=    0 loss=0.053941  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056594  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059111  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.054784  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.055579  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.053850  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.029756
# @valid_loop avg_loss=0.029802
#
# Epoch 64
# -------------------------------
# @train_loop batch=    0 loss=0.054262  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.061540  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.053390  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.053677  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.050597  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.053792  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030825
# @valid_loop avg_loss=0.030857
#
# Epoch 65
# -------------------------------
# @train_loop batch=    0 loss=0.053399  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056816  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059900  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.059034  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.053922  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.052388  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030624
# @valid_loop avg_loss=0.030662
#
# Epoch 66
# -------------------------------
# @train_loop batch=    0 loss=0.058112  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056842  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057607  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.055493  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.051219  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.058735  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030761
# @valid_loop avg_loss=0.030796
#
# Epoch 67
# -------------------------------
# @train_loop batch=    0 loss=0.051939  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.055954  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.060457  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.052127  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.055775  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.053255  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030792
# @valid_loop avg_loss=0.030833
#
# Epoch 68
# -------------------------------
# @train_loop batch=    0 loss=0.058217  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.059651  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.052711  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.054994  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.055084  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.052501  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030523
# @valid_loop avg_loss=0.030555
#
# Epoch 69
# -------------------------------
# @train_loop batch=    0 loss=0.057351  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.055194  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057516  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.061236  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.056944  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057108  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030703
# @valid_loop avg_loss=0.030738
#
# Epoch 70
# -------------------------------
# @train_loop batch=    0 loss=0.060306  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.054498  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.053471  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.053110  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.055680  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.055767  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031063
# @valid_loop avg_loss=0.031096
#
# Epoch 71
# -------------------------------
# @train_loop batch=    0 loss=0.057067  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.055977  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.056336  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.053816  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057405  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.060178  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030126
# @valid_loop avg_loss=0.030164
#
# Epoch 72
# -------------------------------
# @train_loop batch=    0 loss=0.057797  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056338  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.056733  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.054069  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.059805  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057781  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030882
# @valid_loop avg_loss=0.030907
#
# Epoch 73
# -------------------------------
# @train_loop batch=    0 loss=0.055020  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.055331  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.053487  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.055389  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.054228  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.055419  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030769
# @valid_loop avg_loss=0.030786
#
# Epoch 74
# -------------------------------
# @train_loop batch=    0 loss=0.057022  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057634  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.053965  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058107  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.059707  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.060045  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030882
# @valid_loop avg_loss=0.030913
#
# Epoch 75
# -------------------------------
# @train_loop batch=    0 loss=0.055768  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.057355  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059011  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056379  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.059390  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.059362  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030415
# @valid_loop avg_loss=0.030459
#
# Epoch 76
# -------------------------------
# @train_loop batch=    0 loss=0.054160  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.060351  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057015  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058112  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057362  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.052977  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030640
# @valid_loop avg_loss=0.030679
#
# Epoch 77
# -------------------------------
# @train_loop batch=    0 loss=0.057400  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.061134  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059789  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056218  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057420  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.056907  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031008
# @valid_loop avg_loss=0.031044
#
# Epoch 78
# -------------------------------
# @train_loop batch=    0 loss=0.056660  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.051527  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.056873  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056916  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058976  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.051464  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030505
# @valid_loop avg_loss=0.030542
#
# Epoch 79
# -------------------------------
# @train_loop batch=    0 loss=0.048299  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.059762  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.056724  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.049966  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.055594  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.060433  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030808
# @valid_loop avg_loss=0.030845
#
# Epoch 80
# -------------------------------
# @train_loop batch=    0 loss=0.056318  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.053107  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059388  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.060186  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.052087  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.057629  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031234
# @valid_loop avg_loss=0.031265
#
# Epoch 81
# -------------------------------
# @train_loop batch=    0 loss=0.057624  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.058018  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.053804  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056240  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058413  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.059361  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030853
# @valid_loop avg_loss=0.030884
#
# Epoch 82
# -------------------------------
# @train_loop batch=    0 loss=0.058429  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.053956  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.060726  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058189  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.055287  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.055496  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030673
# @valid_loop avg_loss=0.030703
#
# Epoch 83
# -------------------------------
# @train_loop batch=    0 loss=0.055221  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.054837  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.058826  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056952  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.054410  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.054281  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031238
# @valid_loop avg_loss=0.031273
#
# Epoch 84
# -------------------------------
# @train_loop batch=    0 loss=0.054528  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.049965  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.055742  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056214  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.053701  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.053144  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031038
# @valid_loop avg_loss=0.031072
#
# Epoch 85
# -------------------------------
# @train_loop batch=    0 loss=0.058714  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056386  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.054323  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058433  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.055450  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.059475  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030983
# @valid_loop avg_loss=0.031005
#
# Epoch 86
# -------------------------------
# @train_loop batch=    0 loss=0.059819  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.055922  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.055240  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058646  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057121  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.059918  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030971
# @valid_loop avg_loss=0.031011
#
# Epoch 87
# -------------------------------
# @train_loop batch=    0 loss=0.056100  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.058883  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059079  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058237  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.057785  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.058200  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031033
# @valid_loop avg_loss=0.031063
#
# Epoch 88
# -------------------------------
# @train_loop batch=    0 loss=0.058732  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.058322  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.055588  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.059042  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.052821  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.058229  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030965
# @valid_loop avg_loss=0.030993
#
# Epoch 89
# -------------------------------
# @train_loop batch=    0 loss=0.054548  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.061716  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059630  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.051730  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058536  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.055012  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030697
# @valid_loop avg_loss=0.030721
#
# Epoch 90
# -------------------------------
# @train_loop batch=    0 loss=0.059989  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.054960  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.055159  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.053001  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.059374  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.061387  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031358
# @valid_loop avg_loss=0.031377
#
# Epoch 91
# -------------------------------
# @train_loop batch=    0 loss=0.055771  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.058930  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.055707  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.053983  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.056510  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.059770  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031707
# @valid_loop avg_loss=0.031727
#
# Epoch 92
# -------------------------------
# @train_loop batch=    0 loss=0.058552  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.059229  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.060945  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.060676  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.053563  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.052014  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030877
# @valid_loop avg_loss=0.030911
#
# Epoch 93
# -------------------------------
# @train_loop batch=    0 loss=0.054722  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056108  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.056937  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.052201  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.054480  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.055689  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031715
# @valid_loop avg_loss=0.031738
#
# Epoch 94
# -------------------------------
# @train_loop batch=    0 loss=0.054412  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.053306  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.053418  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.054707  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.052944  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.059645  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031802
# @valid_loop avg_loss=0.031828
#
# Epoch 95
# -------------------------------
# @train_loop batch=    0 loss=0.060529  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.054302  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.061324  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.050978  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.054971  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.056088  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031401
# @valid_loop avg_loss=0.031429
#
# Epoch 96
# -------------------------------
# @train_loop batch=    0 loss=0.058210  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.058702  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.058450  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056516  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.056538  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.056276  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031409
# @valid_loop avg_loss=0.031439
#
# Epoch 97
# -------------------------------
# @train_loop batch=    0 loss=0.049988  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.052141  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.053630  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.055573  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.056583  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.056977  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031954
# @valid_loop avg_loss=0.031978
#
# Epoch 98
# -------------------------------
# @train_loop batch=    0 loss=0.053384  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.054426  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.057623  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.059993  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.058154  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.054811  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.031184
# @valid_loop avg_loss=0.031221
#
# Epoch 99
# -------------------------------
# @train_loop batch=    0 loss=0.054385  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.056100  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.055442  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.058148  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.056886  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.052145  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030978
# @valid_loop avg_loss=0.031007
#
# Epoch 100
# -------------------------------
# @train_loop batch=    0 loss=0.063766  muestras-procesadas=[    0/60000]
# @train_loop batch=  100 loss=0.059102  muestras-procesadas=[10000/60000]
# @train_loop batch=  200 loss=0.059443  muestras-procesadas=[20000/60000]
# @train_loop batch=  300 loss=0.056234  muestras-procesadas=[30000/60000]
# @train_loop batch=  400 loss=0.053974  muestras-procesadas=[40000/60000]
# @train_loop batch=  500 loss=0.050889  muestras-procesadas=[50000/60000]
# @valid_loop avg_loss=0.030924
# @valid_loop avg_loss=0.030962
# Done!

# %%
# 5.10)
plt.xlabel('epoch')
plt.ylabel('loss')
#plt.xlim(-0.1,5.1)
#plt.ylim(-0.1,1.1)
plt.plot(range(1,len(list_train_avg_loss_incorrecta)+1),list_train_avg_loss_incorrecta,label="train-incorr",linestyle='-',c='red')
plt.plot(range(1,len(list_train_avg_loss)+1),list_train_avg_loss,label="train",linestyle='-.',c='green')
plt.plot(range(1,len(list_valid_avg_loss)+1),list_valid_avg_loss,label="valid",linestyle='--',c='blue')
plt.title('')
plt.legend()

# %%
plt.xlabel('epoch')
plt.ylabel('loss')
#plt.xlim(-0.1,5.1)
#plt.ylim(-0.1,1.1)
plt.plot(range(1,len(list_train_avg_loss)+1),list_train_avg_loss,label="train",linestyle='-.',c='green')
plt.plot(range(1,len(list_valid_avg_loss)+1),list_valid_avg_loss,label="valid",linestyle='--',c='blue')
plt.title('')
plt.legend()

# %%
# Miramos que imagenes predice el modelo sin entrenar
figure = plt.figure()
rows,cols = 3,2
i = 0 # subplot index
for row in range(1,rows+1):
    j = torch.randint(len(train_set_orig),size=(1,)).item() # elegimos un elemento random de el conjunto de entrenamiento
    # Ploteamos la imagen original
    i += 1
    image,flatten_imagen = train_set_orig[j]
    figure.add_subplot(rows,cols,i)
    if row==1: # le ponemos titulo solo a la primera imagen
      plt.title("original")
    plt.axis("off")
    plt.imshow(unbatch(image),cmap="Greys_r") # plotemaos la original
    # Ploteamos la imagen predicha
    i += 1
    figure.add_subplot(rows,cols,i)
    if row==1:
      plt.title("predicha")
    plt.axis("off")
    image_pred = unbatch(model(batch(image)))
    plt.imshow(image_pred,cmap="Greys_r")
plt.show()
